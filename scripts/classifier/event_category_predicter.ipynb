# %%
import sys
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')
#warnings.filterwarnings(action='once')

# %% [markdown]
# ## Data Treatment

# %%
df_all= pd.read_csv('meetup.csv')
df_all.head(1)
# Out:
#                                          description    status   event_id  \
# 0  <p>FOOD AND FELLOWSHIP | 5 PM</p> \n<p>CONCERT...  upcoming  239660020
#
#                   event_name category
# 0  We Are Messengers Concert  singles

# %%
df=df_all[["description", "event_id", "category"]]
del df_all
df.head(1)
# Out:
#                                          description   event_id category
# 0  <p>FOOD AND FELLOWSHIP | 5 PM</p> \n<p>CONCERT...  239660020  singles

# %%
df.shape
# Out:
# (195319, 3)

# %%
df=df.dropna()
df.shape
# Out:
# (179883, 3)

# %%
df.category.value_counts()
# Out:
# outdoors/adventure          18869
# socializing                 18292
# tech                        17532
# career/business             17144
# health/wellbeing            16927
# new age/spirituality        10784
# sports/recreation            8721
# fitness                      8019
# language/ethnic identity     7567
# food/drink                   5156
# games                        5089
# fine arts/culture            4140
# dancing                      4099
# education/learning           3613
# music                        3435
# movements/politics           3355
# community/environment        3142
# singles                      2838
# religion/beliefs             2721
# parents/family               2376
# photography                  2128
# hobbies/crafts               1913
# movies/film                  1846
# LGBT                         1574
# support                      1559
# writing                      1328
# book clubs                   1289
# ...

# %%
category_list=list(df.category.unique())
category_list=[str(elem) for elem in category_list]
category_list.sort()
category_list
# Out:
# ['LGBT',
#  'alternative lifestyle',
#  'book clubs',
#  'career/business',
#  'cars/motorcycles',
#  'community/environment',
#  'dancing',
#  'education/learning',
#  'fashion/beauty',
#  'fine arts/culture',
#  'fitness',
#  'food/drink',
#  'games',
#  'health/wellbeing',
#  'hobbies/crafts',
#  'language/ethnic identity',
#  'movements/politics',
#  'movies/film',
#  'music',
#  'new age/spirituality',
#  'outdoors/adventure',
#  'paranormal',
#  'parents/family',
#  'pets/animals',
#  'photography',
#  'religion/beliefs',
#  'sci-fi/fantasy',
#  'singles',
#  'socializing',
#  'sports/recreation',
#  'support',
#  'tech',
#  'writing']

# %%
df['category_bin']=0

for count,category in enumerate(category_list):
    for row in df.itertuples():
        if row.category == category:
            df.at[row.Index,'category_bin']=count

# %%
df=df[["description", "category_bin"]]
df.head()
# Out:
#                                          description  category_bin
# 0  <p>FOOD AND FELLOWSHIP | 5 PM</p> \n<p>CONCERT...            27
# 1  <p><b>【WhyNot!?JAPAN + MeetUp Collaboration Ev...            28
# 2  <p>TENTATIVE<br></p>\n<p><br></p>\n<p>10.30 - ...            31
# 3  <p><span>Hey explorersssss, what's up?</span><...            15
# 4  <p>Free, unauditioned, collaborative pop choir...            18

# %% [markdown]
# ## Lang detection

# %%
try:
    from polyglot.detect import Detector
except ImportError:
    #!pip install --user pyicu pycld2
    # !pip install polyglot --user

    from polyglot.detect import Detector

europ_languages = ['danish', 'dutch', 'english', 'finnish', 'french', 'german', 'hungarian', 'italian', 'norwegian', 'portuguese', 'russian', 'spanish', 'swedish', 'turkish']

df["lang_ok"]="NaN"
for count, row in enumerate(df.itertuples()):
        try:
            langs=Detector(row.description).languages
            lang=langs[0].name.lower()
            if lang in europ_languages:
                #print(count,lang)
                df.at[row.Index, "lang_ok"]=lang
        except:
            pass
# Out:
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# ...

# %%
df=df[df["lang_ok"]!="NaN"]
df.shape
# Out:
# (174887, 3)

# %%
df=df[df["lang_ok"]=="english"]
df.shape
# Out:
# (163543, 3)

# %%
#!pip install --user translate
from translate import Translator
translator= Translator(from_lang="it", to_lang="en")

# %%
translation = translator.translate("Ciao come va?")
translation
# Out:
# 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  03 HOURS 42 MINUTES 44 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE'

# %% [markdown]
# ## Proper processing

# %%
#trans.translate("yolo", dest="en")
#tr.text

# %%
import re
import sys
import time

#!pip install googletrans --user
import googletrans
try:
    import pydeepl
except:
    # !pip install pydeepl --user
    import pydeepl
try:
    import nltk
except ImportError:
    # !pip install nltk
    import nltk
    nltk.download('stopwords')

from nltk.stem.snowball import SnowballStemmer, PorterStemmer

try:
    from bs4 import BeautifulSoup 
except ImportError:
    # !pip install bs4 --user
    from bs4 import BeautifulSoup 
    
try:
    from langdetect import detect
except ImportError:
    # !pip install langdetect --user
    from langdetect import detect

try:
    from polyglot.detect import Detector
except ImportError:
    #!pip install --user pyicu pycld2
    # !pip install polyglot --user

    from polyglot.detect import Detector
try: 
    import emoji
except ImportError:
    # !pip install emoji --user
    
def give_emoji_free_text(text):
    allchars = [str for str in text]
    emoji_list = [c for c in allchars if c in emoji.UNICODE_EMOJI]
    clean_text = ' '.join([str for str in text.split() if not any(i in str for i in emoji_list)])

    return clean_text

#translator = Translator()
#give_emoji_free_text(<your message>)
#translator.translate(give_emoji_free_text(<your message>), dest = 'en').text
    
Snowball_languages = (
       "arabic",
       "danish",
       "dutch",
       "english",
       "finnish",
       "french",
       "german",
       "hungarian",
       "italian",
       "norwegian",
       "porter",
       "portuguese",
       "romanian",
       "russian",
       "spanish",
       "swedish",
)

bad_words=["www", "http", "https", "th", "pm", "ticket", "org", "event", "link", "registr",
               "meetup", "event", "group", "regist", "pleas", "please", "join", "rsvp", "member", 
               "venu", "free", "comment", "thank", "attend", "eventbrit", "mr", "st", "rd", "hour", "new", "time", 
               "boston", "like"]
    
def clean_description(desc):
    stemm=False
    try:
        #html_less = BeautifulSoup(desc).get_text() 
        html_less=BeautifulSoup(desc,"lxml").text
    except Exception as e:
        #print(e)
        html_less=str(desc)
    #rm punctuation
    #for lang in Detector(html_less).languages:
    #    print(lang)
    html_less= re.sub(r'^https?:\/\/.*[\r\n]*', '', html_less, flags=re.MULTILINE)
    
    no_emoj=give_emoji_free_text(html_less)
    
    try:
        langs=Detector(no_emoj).languages
        lang=langs[0].name.lower()        
    except:
        print(no_emoj,"--",desc)
        stemm=False
        return "Error"
        
    try:
        if lang != "english":      
                #translator = Translator()
                #no_emoj=translator.translate(no_emoj, src=langs[0].code, dest = 'en').text
                #time.sleep(0.01)
                #no_emoj = pydeepl.translate(no_emoj, "EN", from_lang=langs[0].code.upper())
                translator= Translator(from_lang=langs[0].code, to_lang="en")
                no_emoj = translator.translate(no_emoj)
                if no_emoj== 'MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  13 HOURS 32 MINUTES 18 SECONDSVISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE':
                    print("ERROR")
                #translation
    except Exception as e:
            #%tb
        print("####",e,"####")
        #sys.exit()
        return "Error"
    
    #no_punct = re.sub("[^a-zA-Z]", " ", no_emoj)
    no_punct=no_emoj.replace("|","").replace("!","").replace("?","")
    
    tokens = no_punct.lower().split()
    #tokens = no_punct.lower().split()
    
    #nltk supported lang
    europ_languages = ['danish', 'dutch', 'english', 'finnish', 'french', 'german', 'hungarian', 'italian', 'norwegian', 'portuguese', 'russian', 'spanish', 'swedish', 'turkish']
    #europ_languages=nltk.corpus.stopwords.fileids()
    
    no_tokens = set(nltk.corpus.stopwords.words(europ_languages))                  
    #print(my_stop_words)
    #no_stop_tokens = [token for token in tokens if token not in no_tokens and token not in bad_words]  
    no_stop_tokens = [token for token in tokens if all([token not in no_tokens, token not in bad_words])]  
    #print(no_stop_tokens)
    if stemm:
        #if lang in Snowball_languages:
        #    Stemmer=SnowballStemmer(lang.lower())
        Stemmer = PorterStemmer()
        stemmed = [Stemmer.stem(elem) for elem in no_stop_tokens]
        return( " ".join(stemmed))
       
    return( " ".join(no_stop_tokens))

# %%
#not good witht the google api

from multiprocessing import cpu_count, Pool

cores = cpu_count() #Number of CPU cores on your system
#cores=2
partitions = cores #Define as many partitions as you want

def parallelize(data, func):
    data_split = np.array_split(data, partitions)
    pool = Pool(cores)
    data = pd.concat(pool.map(func, data_split))
    pool.close()
    pool.join()
    return data
#df["yolo"]="NaN"
def test_func(data):
    #print "Process working on: ",data
    data['processed_description'] = data.description.map(clean_description)
    return data

df['processed_description'] = "NaN"

df = parallelize(df, test_func)
# Out:
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
#  -- <p><a href="http://www.tigerbalmtrail.com/" class="linkified">http://www.tigerbalmtrail.com/</a></p>
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# ...

# %%
"""desc_try=df['description'][0]
desc_try

clean_description(desc_try)""";

# %%
"""df['processed_description'] = "NaN"
df['processed_description'] = df.description.map(clean_description)"""
df.head(50)
# Out:
#                                             description  category_bin  \
# 11    <p>ATENCIÓN APLAZADO AL DOMINGO 14.</p>\n<p><s...            19
# 15    <p>Este trabajo estará enfocado en una nueva f...            19
# 27    <p><a href="https://www.meetup.com/codecentric...            31
# 29    <p>Nefes koçu Neslihan Canıoğlu ile nefes egze...             3
# 34    <p>Смотрим Google I/O вместе! &nbsp;</p>\n<p>С...            31
# 42    <p>L’école de langues Languages.lu et l'Ambass...             3
# 44    <p><i>ATELIER POUR LES NOUVEAUX</i><br></p>\n<...            13
# 45    <p>This event is hosted by Codecentric, please...            31
# 732   <p><img src="https://secure.meetupstatic.com/p...            31
# 858   <p><img src="https://secure.meetupstatic.com/p...            20
# 877   <p>Sólo tienes que traer ropa cómoda y ganas d...            13
# 878   <p>Sólo tienes que traer ropa cómoda y ganas d...            13
# ...

# %%
df[df["lang_ok"]=="english"]["processed_description"]
# Out:
# Series([], Name: processed_description, dtype: object)

# %%
def clean_description(desc):
    #good_words=[elem for elem in desc.split() if elem not in bad_words]
    desc=desc.replace("|","").replace("!","").replace("?","")
    return ' '.join(desc)


"""desc_try=df['description'][0]
desc_try

clean_description(desc_try)""";

from multiprocessing import cpu_count, Pool

cores = cpu_count() #Number of CPU cores on your system
cores=4
partitions = cores #Define as many partitions as you want

def parallelize(data, func):
    data_split = np.array_split(data, partitions)
    pool = Pool(cores)
    data = pd.concat(pool.map(func, data_split))
    pool.close()
    pool.join()
    return data
#df["yolo"]="NaN"
def test_func(data):
    #print "Process working on: ",data
    data['processed_description'] = data.processed_description.map(clean_description)
    return data

df = parallelize(df, test_func)

# %%
#df.to_csv("processed_description_sine_error_Porter.csv")

# %%
df[df["processed_description"]=="Error"]["description"]#.count()
# Out:
# 1581      <p><img src="https://secure.meetupstatic.com/p...
# 1985      <p><img src="https://secure.meetupstatic.com/p...
# 3352      <p><a href="http://www.radioradicale.it/" clas...
# 3353      <p><a href="http://www.radioradicale.it/" clas...
# 3735      <p><a href="http://www.radioradicale.it/" clas...
# 5032      <p><a href="http://szjug.github.io/#April2017"...
# 5372      <p>https://www.facebook.com/events/25124068195...
# 5588      <p><br></p>\n<p><a class="embedded" href="http...
# 5856      <p><a href="https://www.ubs.com/microsites/ann...
# 6102      <p><a href="https://journeytomybestself.com/cl...
# 6452      <p>http://www.antoniabehan.com/coachingcircle....
# 6928      <p>https://webmail2.comune.bergamo.it/gestione...
# 7379           <p>http://tertuliajapon.blogspot.com.es/</p>
# 8231      <p><a href="http://acca.melbourne/program/clai...
# 8249      <p><a href="https://www.eventbrite.com/e/north...
# 8405      <p>http://www.forrodedomingo.de/startseite.htm...
# ...

# %%
df.shape
# Out:
# (174887, 4)

# %%
df=df[df["processed_description"]!="Error"]
df.shape
# Out:
# (174438, 4)

# %%
df.to_csv("processed_description_only_eng_no_bad_words_and_stopwords.csv")

# %%
#tri=pd.read_csv("processed_description.csv")
#del tri

# %% [markdown]
# ### Summary

# %%
print("word count (tot):", sum(df['processed_description'].str.split().map(lambda x: len(x))))
print("average word count per description:", int(sum(df['processed_description'].str.split().map(lambda x: len(x)))/(df['processed_description'].shape[0])))

unique_words = set()
df['processed_description'].str.split().map(unique_words.update)
print("total unique words:", len(unique_words))

print("--------------------------------")

from collections import Counter
wc = Counter()
df['processed_description'].str.split().map(wc.update)
print("top 20 most common words:", wc.most_common(20))
# Out:
# word count (tot): 17196336
# average word count per description: 98
# total unique words: 166880
# --------------------------------
# top 20 most common words: [('us', 94411), ('get', 88854), ('meet', 87620), ('one', 73440), ('peopl', 70781), ('bring', 68646), ('make', 67632), ('day', 63856), ('sail', 62736), ('may', 62111), ('learn', 60275), ('park', 58727), ('mask', 58669), ('use', 58493), ('class', 58473), ('go', 56587), ('need', 54396), ('work', 50700), ('start', 50614), ('nation', 50130)]

# %% [markdown]
# ## Classification

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import classification_report, roc_curve, auc

# %%
X_data = df['processed_description']
Y_data = df['category_bin']

X_train, X_test, Y_train, Y_test = train_test_split(X_data, Y_data, test_size=.25)

# %%
tf_vectorizer = TfidfVectorizer(analyzer = "word", tokenizer = None, norm = 'l1',
                                preprocessor = None, max_features = 10000)

# %%
X_train_tfidf = tf_vectorizer.fit_transform(X_train)
#X_train_tfidf = X_train_tfidf.toarray()
X_train_tfidf.shape
# Out:
# (130828, 10000)

# %%
vocab = tf_vectorizer.get_feature_names()
len(vocab)
# Out:
# 10000

# %%
forest = RandomForestClassifier(n_jobs=6)#, n_estimators=50) 
forest = forest.fit(X_train_tfidf, Y_train)

# %%
X_test_vec_tf = tf_vectorizer.transform(X_test)
X_test_vec_tf = X_test_vec_tf.toarray()

# %%
forest.score(X_test_vec_tf, Y_test)#100 est
# Out:
# 0.7185049300619124

# %%
forest.score(X_test_vec_tf, Y_test)#10feat
# Out:
# 0.6893831689979363

# %%
forest.score(X_test_vec_tf, Y_test)#2000feat
# Out:
# 0.722949335812315

# %%
forest.score(X_test_vec_tf, Y_test)#10000feat
# Out:
# 0.7216038358979378

# %%
predictions = forest.predict(X_test_vec_tf)

# %%
print(metrics.classification_report(Y_test, predictions)) #100 features
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.46      0.58       392
#            1       0.93      0.77      0.84       172
#            2       0.55      0.49      0.52       315
#            3       0.70      0.76      0.73      4120
#            4       0.80      0.60      0.68       317
#            5       0.67      0.42      0.52       730
#            6       0.75      0.78      0.76       985
#            7       0.72      0.52      0.61       884
#            8       0.78      0.36      0.49       101
#            9       0.72      0.53      0.61       991
#           10       0.74      0.72      0.73      2063
#           11       0.67      0.61      0.64      1218
#           12       0.73      0.79      0.76      1215
#           13       0.68      0.73      0.71      4100
#           14       0.79      0.53      0.63       452
#           15       0.75      0.58      0.65      1722
# ...

# %%
print(metrics.classification_report(Y_test, predictions)) #1000 features
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.48      0.58       390
#            1       0.88      0.78      0.83       151
#            2       0.56      0.52      0.54       309
#            3       0.69      0.82      0.75      3828
#            4       0.77      0.58      0.66       331
#            5       0.61      0.46      0.52       718
#            6       0.76      0.84      0.80       943
#            7       0.68      0.54      0.60       782
#            8       0.79      0.37      0.51        83
#            9       0.68      0.59      0.63       912
#           10       0.74      0.75      0.74      1904
#           11       0.65      0.59      0.62      1273
#           12       0.72      0.81      0.76      1243
#           13       0.69      0.78      0.73      3782
#           14       0.75      0.51      0.60       410
#           15       0.73      0.67      0.70      1499
# ...

# %%
print(metrics.classification_report(Y_test, predictions)) #2000 features
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.49      0.61       390
#            1       0.94      0.79      0.86       151
#            2       0.54      0.50      0.52       309
#            3       0.70      0.82      0.76      3828
#            4       0.79      0.63      0.70       331
#            5       0.69      0.47      0.56       718
#            6       0.76      0.84      0.80       943
#            7       0.72      0.55      0.63       782
#            8       0.79      0.36      0.50        83
#            9       0.72      0.60      0.65       912
#           10       0.75      0.74      0.75      1904
#           11       0.69      0.62      0.66      1273
#           12       0.72      0.83      0.77      1243
#           13       0.69      0.80      0.74      3782
#           14       0.75      0.56      0.64       410
#           15       0.76      0.67      0.71      1499
# ...

# %%
print(metrics.classification_report(Y_test, predictions)) #10000 features
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.50      0.61       390
#            1       0.87      0.78      0.82       151
#            2       0.54      0.49      0.51       309
#            3       0.70      0.83      0.76      3828
#            4       0.80      0.60      0.69       331
#            5       0.73      0.47      0.57       718
#            6       0.74      0.85      0.79       943
#            7       0.74      0.54      0.63       782
#            8       0.82      0.39      0.52        83
#            9       0.72      0.60      0.65       912
#           10       0.75      0.75      0.75      1904
#           11       0.67      0.59      0.63      1273
#           12       0.72      0.82      0.77      1243
#           13       0.69      0.79      0.74      3782
#           14       0.79      0.52      0.63       410
#           15       0.77      0.67      0.71      1499
# ...
